# %%
import pandas as pd

# %%
sales_df = pd.read_csv('./data/sales_data_sample.csv', encoding='ISO-8859-1')
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
total_nulos = sales_df.isnull().sum().sort_values(ascending=False)
pct_nulos = sales_df.isnull().sum()/sales_df.isnull().count()
pct_nulos
# Out:
# ORDERNUMBER         0.000000
# QUANTITYORDERED     0.000000
# PRICEEACH           0.000000
# ORDERLINENUMBER     0.000000
# SALES               0.000000
# ORDERDATE           0.000000
# STATUS              0.000000
# QTR_ID              0.000000
# MONTH_ID            0.000000
# YEAR_ID             0.000000
# PRODUCTLINE         0.000000
# MSRP                0.000000
# PRODUCTCODE         0.000000
# CUSTOMERNAME        0.000000
# PHONE               0.000000
# ADDRESSLINE1        0.000000
# ADDRESSLINE2        0.893022
# CITY                0.000000
# STATE               0.526390
# POSTALCODE          0.026922
# COUNTRY             0.000000
# TERRITORY           0.380446
# CONTACTLASTNAME     0.000000
# CONTACTFIRSTNAME    0.000000
# DEALSIZE            0.000000
# dtype: float64

# %%
sales_df.select_dtypes(include=['int','float'])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       QTR_ID  MONTH_ID  YEAR_ID  MSRP
# 0          1         2     2003    95
# 1          2         5     2003    95
# 2          3         7     2003    95
# 3          3         8     2003    95
# 4          4        10     2003    95
# ...      ...       ...      ...   ...
# 2818       4        12     2004    54
# 2819       1         1     2005    54
# 2820       1         3     2005    54
# 2821       1         3     2005    54
# 2822       2         5     2005    54
#
# [2823 rows x 9 columns]

# %%
sales_df[['CUSTOMERNAME','CONTACTFIRSTNAME']]
# Out:
#                   CUSTOMERNAME CONTACTFIRSTNAME
# 0            Land of Toys Inc.             Kwai
# 1           Reims Collectables             Paul
# 2              Lyon Souveniers           Daniel
# 3            Toys4GrownUps.com            Julie
# 4     Corporate Gift Ideas Co.            Julie
# ...                        ...              ...
# 2818     Euro Shopping Channel            Diego
# 2819   Oulu Toy Supplies, Inc.           Pirkko
# 2820     Euro Shopping Channel            Diego
# 2821              Alpha Cognac          Annette
# 2822         Gifts4AllAges.com             Juri
#
# [2823 rows x 2 columns]

# %%
sales_df[sales_df.columns[1:5]]
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES
# 0                  30      95.70                2  2871.00
# 1                  34      81.35                5  2765.90
# 2                  41      94.74                2  3884.34
# 3                  45      83.26                6  3746.70
# 4                  49     100.00               14  5205.27
# ...               ...        ...              ...      ...
# 2818               20     100.00               15  2244.40
# 2819               29     100.00                1  3978.51
# 2820               43     100.00                4  5417.57
# 2821               34      62.24                1  2116.16
# 2822               47      65.52                9  3079.44
#
# [2823 rows x 4 columns]

# %%
booleanMask = sales_df.columns.isin(['CUSTOMERNAME','CONTACTFIRSTNAME'])
selectColumn = sales_df.columns[booleanMask]
selectColumn
sales_df[selectColumn]
# Out:
#                   CUSTOMERNAME CONTACTFIRSTNAME
# 0            Land of Toys Inc.             Kwai
# 1           Reims Collectables             Paul
# 2              Lyon Souveniers           Daniel
# 3            Toys4GrownUps.com            Julie
# 4     Corporate Gift Ideas Co.            Julie
# ...                        ...              ...
# 2818     Euro Shopping Channel            Diego
# 2819   Oulu Toy Supplies, Inc.           Pirkko
# 2820     Euro Shopping Channel            Diego
# 2821              Alpha Cognac          Annette
# 2822         Gifts4AllAges.com             Juri
#
# [2823 rows x 2 columns]

# %%
sales_df.filter(like='ORDER')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER        ORDERDATE
# 0           10107               30                2   2/24/2003 0:00
# 1           10121               34                5    5/7/2003 0:00
# 2           10134               41                2    7/1/2003 0:00
# 3           10145               45                6   8/25/2003 0:00
# 4           10159               49               14  10/10/2003 0:00
# ...           ...              ...              ...              ...
# 2818        10350               20               15   12/2/2004 0:00
# 2819        10373               29                1   1/31/2005 0:00
# 2820        10386               43                4    3/1/2005 0:00
# 2821        10397               34                1   3/28/2005 0:00
# 2822        10414               47                9    5/6/2005 0:00
#
# [2823 rows x 4 columns]

# %%
sales_df['STATE'].fillna(value='NY',inplace=True)
sales_df['STATE']

# %%
sales_df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE                  0
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
sales_df[(sales_df.STATE == 'NY') & (sales_df.QTR_ID == 2)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 11          10237               23     100.00                7  2333.12
# 24          10403               24     100.00                7  2434.56
# 25          10417               66     100.00                2  7516.08
# 28          10126               38     100.00               11  7329.06
# ...           ...              ...        ...              ...      ...
# 2771        10119               28      48.17                6  1348.76
# 2782        10262               21      57.11               12  1199.31
# 2798        10117               50      43.68                2  2184.00
# 2799        10129               32      64.97                8  2079.04
# 2809        10248               23      65.52                9  1506.96
#
#            ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1      5/7/2003 0:00    Shipped       2         5     2003  ...
# 11     4/5/2004 0:00    Shipped       2         4     2004  ...
# 24     4/8/2005 0:00    Shipped       2         4     2005  ...
# 25    5/13/2005 0:00   Disputed       2         5     2005  ...
# 28    5/28/2003 0:00    Shipped       2         5     2003  ...
# ...              ...        ...     ...       ...      ...  ...
# 2771  4/28/2003 0:00    Shipped       2         4     2003  ...
# 2782  6/24/2004 0:00  Cancelled       2         6     2004  ...
# 2798  4/16/2003 0:00    Shipped       2         4     2003  ...
# 2799  6/12/2003 0:00    Shipped       2         6     2003  ...
# 2809   5/7/2004 0:00  Cancelled       2         5     2004  ...
#
#                               ADDRESSLINE1  ADDRESSLINE2       CITY STATE  \
# 1                       59 rue de l'Abbaye           NaN      Reims    NY
# 11                       2678 Kingston Rd.     Suite 101        NYC    NY
# 24            Berkeley Gardens 12  Brewery           NaN  Liverpool    NY
# 25                      C/ Moralzarzal, 86           NaN     Madrid    NY
# 28                          C/ Araquil, 67           NaN     Madrid    NY
# ...                                    ...           ...        ...   ...
# 2771                           Geislweg 14           NaN   Salzburg    NY
# 2782                    C/ Moralzarzal, 86           NaN     Madrid    NY
# 2798  Bronz Sok., Bronz Apt. 3/6 Tesvikiye           NaN  Singapore    NY
# 2799                        35 King George           NaN     London    NY
# 2809               897 Long Airport Avenue           NaN        NYC    NY
#
#      POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 1         51100     France      EMEA         Henriot             Paul    Small
# 11        10022        USA       NaN           Frick          Michael    Small
# 24      WX1 6LT         UK      EMEA           Devon        Elizabeth    Small
# 25        28034      Spain      EMEA          Freyre            Diego    Large
# 28        28023      Spain      EMEA          Sommer           Mart¡n    Large
# ...         ...        ...       ...             ...              ...      ...
# 2771       5020    Austria      EMEA           Pipps            Georg    Small
# 2782      28034      Spain      EMEA          Freyre            Diego    Small
# 2798      79903  Singapore     Japan       Natividad             Eric    Small
# 2799    WX3 6FW         UK      EMEA           Brown              Ann    Small
# 2809      10022        USA       NaN              Yu             Kwai    Small
#
# [344 rows x 25 columns]

# %%
sales_df.query('STATE =="NY" and QTR_ID == 2')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 11          10237               23     100.00                7  2333.12
# 24          10403               24     100.00                7  2434.56
# 25          10417               66     100.00                2  7516.08
# 28          10126               38     100.00               11  7329.06
# ...           ...              ...        ...              ...      ...
# 2771        10119               28      48.17                6  1348.76
# 2782        10262               21      57.11               12  1199.31
# 2798        10117               50      43.68                2  2184.00
# 2799        10129               32      64.97                8  2079.04
# 2809        10248               23      65.52                9  1506.96
#
#            ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1      5/7/2003 0:00    Shipped       2         5     2003  ...
# 11     4/5/2004 0:00    Shipped       2         4     2004  ...
# 24     4/8/2005 0:00    Shipped       2         4     2005  ...
# 25    5/13/2005 0:00   Disputed       2         5     2005  ...
# 28    5/28/2003 0:00    Shipped       2         5     2003  ...
# ...              ...        ...     ...       ...      ...  ...
# 2771  4/28/2003 0:00    Shipped       2         4     2003  ...
# 2782  6/24/2004 0:00  Cancelled       2         6     2004  ...
# 2798  4/16/2003 0:00    Shipped       2         4     2003  ...
# 2799  6/12/2003 0:00    Shipped       2         6     2003  ...
# 2809   5/7/2004 0:00  Cancelled       2         5     2004  ...
#
#                               ADDRESSLINE1  ADDRESSLINE2       CITY STATE  \
# 1                       59 rue de l'Abbaye           NaN      Reims    NY
# 11                       2678 Kingston Rd.     Suite 101        NYC    NY
# 24            Berkeley Gardens 12  Brewery           NaN  Liverpool    NY
# 25                      C/ Moralzarzal, 86           NaN     Madrid    NY
# 28                          C/ Araquil, 67           NaN     Madrid    NY
# ...                                    ...           ...        ...   ...
# 2771                           Geislweg 14           NaN   Salzburg    NY
# 2782                    C/ Moralzarzal, 86           NaN     Madrid    NY
# 2798  Bronz Sok., Bronz Apt. 3/6 Tesvikiye           NaN  Singapore    NY
# 2799                        35 King George           NaN     London    NY
# 2809               897 Long Airport Avenue           NaN        NYC    NY
#
#      POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 1         51100     France      EMEA         Henriot             Paul    Small
# 11        10022        USA       NaN           Frick          Michael    Small
# 24      WX1 6LT         UK      EMEA           Devon        Elizabeth    Small
# 25        28034      Spain      EMEA          Freyre            Diego    Large
# 28        28023      Spain      EMEA          Sommer           Mart¡n    Large
# ...         ...        ...       ...             ...              ...      ...
# 2771       5020    Austria      EMEA           Pipps            Georg    Small
# 2782      28034      Spain      EMEA          Freyre            Diego    Small
# 2798      79903  Singapore     Japan       Natividad             Eric    Small
# 2799    WX3 6FW         UK      EMEA           Brown              Ann    Small
# 2809      10022        USA       NaN              Yu             Kwai    Small
#
# [344 rows x 25 columns]
